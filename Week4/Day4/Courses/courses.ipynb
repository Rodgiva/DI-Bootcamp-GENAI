# %%
import matplotlib.pyplot as plt

# %%
dayofweek = [1,2,3,4,5,6,7]
temperature = [28,29,33,27,30,29,31]
plt.plot(dayofweek, temperature)
plt.show()

# %%
import numpy as np
grades = np.random.randint(low=0, high=101, size=50)
plt.hist(grades, bins=10)
plt.show()
